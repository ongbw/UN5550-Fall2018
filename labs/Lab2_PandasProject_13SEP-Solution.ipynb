# %% [markdown]
# ## 08/13/2018
#
# ## Pandas Excercise
# ​
# Resources:
# * https://pandas.pydata.org/
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
# * https://pandas.pydata.org/pandas-docs/stable/tutorials.html
#
#
#
# Dataset Repository example:
# * https://archive.ics.uci.edu/ml/datasets/Auto+MPG
# * https://archive.ics.uci.edu/ml/index.php
# * https://archive.ics.uci.edu/ml/datasets/Iris
#
# In this project, we will look into Pandas library for data importing(loading), data cleaning, data wrangling and some exploratory data analysis function. The basic plotting and visualization of the data is also aimed for.

# %% [markdown]
# ** Part-I: Importing the following library - pandas, numpy and matplotlib (pyplot) **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Dataset from repository link: https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
#
# Requirements for the import function:
# 1. Function name as " ImportData() "
# 2. Column name would have to be : ** ['mpg', 'cylinders', 'displacement','horsepower','weight', 'acceleration', 'model year', 'origin','car name']. **
# 3. Set the dataframe index (i.e., row labels) to 'car name' which is the last column in dataset.
# 4. Importing function in pandas to be used here are read_csv() or read_table().
#
# Helpful links:
#
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv
# * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html#pandas.read_table

# %%
# Create function name " ImportData() " here,  to import dataset, handle columns and set the column index to car name  
# and return the data.


def ImportData(filename):   
    df=pd.read_csv(filename,header=None,delim_whitespace=True)
    df.columns = ['mpg', 'cylinders', 'displacement','horsepower','weight', 'acceleration', 'model year', 'origin','car name']
    df.index=df['car name']
 
    
#     df is the imported dataframe from the repository. The last column in the data is car name and this needs to be 
    
    return df

filename = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

data = ImportData(filename)
print(data.head())
print(data.index)
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0      130.0  3504.0
# buick skylark 320          15.0          8         350.0      165.0  3693.0
# plymouth satellite         18.0          8         318.0      150.0  3436.0
# amc rebel sst              16.0          8         304.0      150.0  3433.0
# ford torino                17.0          8         302.0      140.0  3449.0
#
#                            acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1
#
#                                             car name
# car name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# Index([u'chevrolet chevelle malibu', u'buick skylark 320',
#        u'plymouth satellite', u'amc rebel sst', u'ford torino',
#        u'ford galaxie 500', u'chevrolet impala', u'plymouth fury iii',
#        u'pontiac catalina', u'amc ambassador dpl',
#        ...
#        u'chrysler lebaron medallion', u'ford granada l', u'toyota celica gt',
#        u'dodge charger 2.2', u'chevrolet camaro', u'ford mustang gl',
#        u'vw pickup', u'dodge rampage', u'ford ranger', u'chevy s-10'],
#       dtype='object', name=u'car name', length=398)

# %%
# Print the data types for the dataframe imported. Observe each columns.

data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data.dropna(how='any')
# Out:
#                                     mpg  cylinders  displacement horsepower  \
# car name
# chevrolet chevelle malibu          18.0          8         307.0      130.0
# buick skylark 320                  15.0          8         350.0      165.0
# plymouth satellite                 18.0          8         318.0      150.0
# amc rebel sst                      16.0          8         304.0      150.0
# ford torino                        17.0          8         302.0      140.0
# ford galaxie 500                   15.0          8         429.0      198.0
# chevrolet impala                   14.0          8         454.0      220.0
# plymouth fury iii                  14.0          8         440.0      215.0
# pontiac catalina                   14.0          8         455.0      225.0
# amc ambassador dpl                 15.0          8         390.0      190.0
# dodge challenger se                15.0          8         383.0      170.0
# plymouth 'cuda 340                 14.0          8         340.0      160.0
# chevrolet monte carlo              15.0          8         400.0      150.0
# buick estate wagon (sw)            14.0          8         455.0      225.0
# toyota corona mark ii              24.0          4         113.0      95.00
# plymouth duster                    22.0          6         198.0      95.00
# amc hornet                         18.0          6         199.0      97.00
# ford maverick                      21.0          6         200.0      85.00
# datsun pl510                       27.0          4          97.0      88.00
# volkswagen 1131 deluxe sedan       26.0          4          97.0      46.00
# peugeot 504                        25.0          4         110.0      87.00
# audi 100 ls                        24.0          4         107.0      90.00
# saab 99e                           25.0          4         104.0      95.00
# bmw 2002                           26.0          4         121.0      113.0
# amc gremlin                        21.0          6         199.0      90.00
# ford f250                          10.0          8         360.0      215.0
# chevy c20                          10.0          8         307.0      200.0
# dodge d200                         11.0          8         318.0      210.0
# hi 1200d                            9.0          8         304.0      193.0
# datsun pl510                       27.0          4          97.0      88.00
# ...                                 ...        ...           ...        ...
# chevrolet cavalier wagon           27.0          4         112.0      88.00
# chevrolet cavalier 2-door          34.0          4         112.0      88.00
# pontiac j2000 se hatchback         31.0          4         112.0      85.00
# dodge aries se                     29.0          4         135.0      84.00
# pontiac phoenix                    27.0          4         151.0      90.00
# ford fairmont futura               24.0          4         140.0      92.00
# amc concord dl                     23.0          4         151.0          ?
# volkswagen rabbit l                36.0          4         105.0      74.00
# mazda glc custom l                 37.0          4          91.0      68.00
# mazda glc custom                   31.0          4          91.0      68.00
# plymouth horizon miser             38.0          4         105.0      63.00
# mercury lynx l                     36.0          4          98.0      70.00
# nissan stanza xe                   36.0          4         120.0      88.00
# honda accord                       36.0          4         107.0      75.00
# toyota corolla                     34.0          4         108.0      70.00
# honda civic                        38.0          4          91.0      67.00
# honda civic (auto)                 32.0          4          91.0      67.00
# datsun 310 gx                      38.0          4          91.0      67.00
# buick century limited              25.0          6         181.0      110.0
# oldsmobile cutlass ciera (diesel)  38.0          6         262.0      85.00
# chrysler lebaron medallion         26.0          4         156.0      92.00
# ford granada l                     22.0          6         232.0      112.0
# toyota celica gt                   32.0          4         144.0      96.00
# dodge charger 2.2                  36.0          4         135.0      84.00
# chevrolet camaro                   27.0          4         151.0      90.00
# ford mustang gl                    27.0          4         140.0      86.00
# vw pickup                          44.0          4          97.0      52.00
# dodge rampage                      32.0          4         135.0      84.00
# ford ranger                        28.0          4         120.0      79.00
# chevy s-10                         31.0          4         119.0      82.00
#
#                                    weight  acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu          3504.0          12.0          70       1
# buick skylark 320                  3693.0          11.5          70       1
# plymouth satellite                 3436.0          11.0          70       1
# amc rebel sst                      3433.0          12.0          70       1
# ford torino                        3449.0          10.5          70       1
# ford galaxie 500                   4341.0          10.0          70       1
# chevrolet impala                   4354.0           9.0          70       1
# plymouth fury iii                  4312.0           8.5          70       1
# pontiac catalina                   4425.0          10.0          70       1
# amc ambassador dpl                 3850.0           8.5          70       1
# dodge challenger se                3563.0          10.0          70       1
# plymouth 'cuda 340                 3609.0           8.0          70       1
# chevrolet monte carlo              3761.0           9.5          70       1
# buick estate wagon (sw)            3086.0          10.0          70       1
# toyota corona mark ii              2372.0          15.0          70       3
# plymouth duster                    2833.0          15.5          70       1
# amc hornet                         2774.0          15.5          70       1
# ford maverick                      2587.0          16.0          70       1
# datsun pl510                       2130.0          14.5          70       3
# volkswagen 1131 deluxe sedan       1835.0          20.5          70       2
# peugeot 504                        2672.0          17.5          70       2
# audi 100 ls                        2430.0          14.5          70       2
# saab 99e                           2375.0          17.5          70       2
# bmw 2002                           2234.0          12.5          70       2
# amc gremlin                        2648.0          15.0          70       1
# ford f250                          4615.0          14.0          70       1
# chevy c20                          4376.0          15.0          70       1
# dodge d200                         4382.0          13.5          70       1
# hi 1200d                           4732.0          18.5          70       1
# datsun pl510                       2130.0          14.5          71       3
# ...                                   ...           ...         ...     ...
# chevrolet cavalier wagon           2640.0          18.6          82       1
# chevrolet cavalier 2-door          2395.0          18.0          82       1
# pontiac j2000 se hatchback         2575.0          16.2          82       1
# dodge aries se                     2525.0          16.0          82       1
# pontiac phoenix                    2735.0          18.0          82       1
# ford fairmont futura               2865.0          16.4          82       1
# amc concord dl                     3035.0          20.5          82       1
# volkswagen rabbit l                1980.0          15.3          82       2
# mazda glc custom l                 2025.0          18.2          82       3
# mazda glc custom                   1970.0          17.6          82       3
# plymouth horizon miser             2125.0          14.7          82       1
# mercury lynx l                     2125.0          17.3          82       1
# nissan stanza xe                   2160.0          14.5          82       3
# honda accord                       2205.0          14.5          82       3
# toyota corolla                     2245.0          16.9          82       3
# honda civic                        1965.0          15.0          82       3
# honda civic (auto)                 1965.0          15.7          82       3
# datsun 310 gx                      1995.0          16.2          82       3
# buick century limited              2945.0          16.4          82       1
# oldsmobile cutlass ciera (diesel)  3015.0          17.0          82       1
# chrysler lebaron medallion         2585.0          14.5          82       1
# ford granada l                     2835.0          14.7          82       1
# toyota celica gt                   2665.0          13.9          82       3
# dodge charger 2.2                  2370.0          13.0          82       1
# chevrolet camaro                   2950.0          17.3          82       1
# ford mustang gl                    2790.0          15.6          82       1
# vw pickup                          2130.0          24.6          82       2
# dodge rampage                      2295.0          11.6          82       1
# ford ranger                        2625.0          18.6          82       1
# chevy s-10                         2720.0          19.4          82       1
#
#                                                             car name
# car name
# chevrolet chevelle malibu                  chevrolet chevelle malibu
# buick skylark 320                                  buick skylark 320
# plymouth satellite                                plymouth satellite
# amc rebel sst                                          amc rebel sst
# ford torino                                              ford torino
# ford galaxie 500                                    ford galaxie 500
# chevrolet impala                                    chevrolet impala
# plymouth fury iii                                  plymouth fury iii
# pontiac catalina                                    pontiac catalina
# amc ambassador dpl                                amc ambassador dpl
# dodge challenger se                              dodge challenger se
# plymouth 'cuda 340                                plymouth 'cuda 340
# chevrolet monte carlo                          chevrolet monte carlo
# buick estate wagon (sw)                      buick estate wagon (sw)
# toyota corona mark ii                          toyota corona mark ii
# plymouth duster                                      plymouth duster
# amc hornet                                                amc hornet
# ford maverick                                          ford maverick
# datsun pl510                                            datsun pl510
# volkswagen 1131 deluxe sedan            volkswagen 1131 deluxe sedan
# peugeot 504                                              peugeot 504
# audi 100 ls                                              audi 100 ls
# saab 99e                                                    saab 99e
# bmw 2002                                                    bmw 2002
# amc gremlin                                              amc gremlin
# ford f250                                                  ford f250
# chevy c20                                                  chevy c20
# dodge d200                                                dodge d200
# hi 1200d                                                    hi 1200d
# datsun pl510                                            datsun pl510
# ...                                                              ...
# chevrolet cavalier wagon                    chevrolet cavalier wagon
# chevrolet cavalier 2-door                  chevrolet cavalier 2-door
# pontiac j2000 se hatchback                pontiac j2000 se hatchback
# dodge aries se                                        dodge aries se
# pontiac phoenix                                      pontiac phoenix
# ford fairmont futura                            ford fairmont futura
# amc concord dl                                        amc concord dl
# volkswagen rabbit l                              volkswagen rabbit l
# mazda glc custom l                                mazda glc custom l
# mazda glc custom                                    mazda glc custom
# plymouth horizon miser                        plymouth horizon miser
# mercury lynx l                                        mercury lynx l
# nissan stanza xe                                    nissan stanza xe
# honda accord                                            honda accord
# toyota corolla                                        toyota corolla
# honda civic                                              honda civic
# honda civic (auto)                                honda civic (auto)
# datsun 310 gx                                          datsun 310 gx
# buick century limited                          buick century limited
# oldsmobile cutlass ciera (diesel)  oldsmobile cutlass ciera (diesel)
# chrysler lebaron medallion                chrysler lebaron medallion
# ford granada l                                        ford granada l
# toyota celica gt                                    toyota celica gt
# dodge charger 2.2                                  dodge charger 2.2
# chevrolet camaro                                    chevrolet camaro
# ford mustang gl                                      ford mustang gl
# vw pickup                                                  vw pickup
# dodge rampage                                          dodge rampage
# ford ranger                                              ford ranger
# chevy s-10                                                chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# **Part II: Data Cleaning** of column indices with car names. Goal of the function "ColDataClean()" is to handle any missing data and also to process the data to produce a character without any spaces in between, for ex: **chevrolet chevelle malibu**.
# The function has to
# 1. Named as ColDataClean()
# 2. Look for any Null/Na entries in the dataframe and delete them.
# 3. Columns labels (headers) are all smaller case (lower), change it to sentence case. following which, replace "space" in the string with the underscore '_'.
# 4. Print all the column index name that has space in between. use *.str.contains()*
# 5. Repeat (3) for index column aswell.

# %%
def ColDataClean(data):
    
    # handle Null type entry below
    print (' ****** Printing any Null entries if any **********')
    print (data.isnull().any())                                   # hint: use isnull().any
    
    
    
                            # Drop null entries look for .notnull() or .dropna()
        
    data.dropna(how='any',inplace=True)
      
    
                            # Drop complete row and also column if all the values are NA
    
    data.dropna(axis=1,how='any',inplace=True)
    
    
                            # This function will drop the row if all the values are NA
    
   



    
    print (' ---------------------Performing String operations on Column head---------------------------')    
    # Handling/cleaning the headers 
    print('Before:', data.columns)
    
    # 1. Change the case of the column names 
    data.columns = data.columns.str.title()

    # 2. the code here must replace the space with '_'
    data.columns = data.columns.str.replace(" ","_")


    print('After: ', data.columns)
    data.columns
    
    
    
    
    
    print (' -------------- Performing String operations on column index i.e., car name ------------------')   
    
    # Handling/cleaning the COLUMN INDEX (str.replace () ) 
    print('Before: ', data.index[data.index.str.contains(' ')]) # Prints all the index that has column names with space 
                                                                #  in it
    
    
    # 1. Change the case of the column names to sentence case
    data.index = data.index.str.title()

    # 2. the code here must replace the space with '_'
    data.index = data.index.str.replace(" ","_")
    
      
    
    
    print('After: ', data.index[data.index.str.contains(' ')])
    
    
    
    return data




data = ColDataClean(data)


data.head()
# Out:
#  ****** Printing any Null entries if any **********
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# car name        False
# dtype: bool
#  ---------------------Performing String operations on Column head---------------------------
# ('Before:', Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight',
#        u'acceleration', u'model year', u'origin', u'car name'],
#       dtype='object'))
# ('After: ', Index([u'Mpg', u'Cylinders', u'Displacement', u'Horsepower', u'Weight',
#        u'Acceleration', u'Model_Year', u'Origin', u'Car_Name'],
#       dtype='object'))
#  -------------- Performing String operations on column index i.e., car name ------------------
# ('Before: ', Index([u'chevrolet chevelle malibu', u'buick skylark 320',
#        u'plymouth satellite', u'amc rebel sst', u'ford torino',
#        u'ford galaxie 500', u'chevrolet impala', u'plymouth fury iii',
#        u'pontiac catalina', u'amc ambassador dpl',
#        ...
#        u'chrysler lebaron medallion', u'ford granada l', u'toyota celica gt',
#        u'dodge charger 2.2', u'chevrolet camaro', u'ford mustang gl',
#        u'vw pickup', u'dodge rampage', u'ford ranger', u'chevy s-10'],
#       dtype='object', name=u'car name', length=396))
# ('After: ', Index([], dtype='object', name=u'car name'))
#                             Mpg  Cylinders  Displacement Horsepower  Weight  \
# car name
# Chevrolet_Chevelle_Malibu  18.0          8         307.0      130.0  3504.0
# Buick_Skylark_320          15.0          8         350.0      165.0  3693.0
# Plymouth_Satellite         18.0          8         318.0      150.0  3436.0
# Amc_Rebel_Sst              16.0          8         304.0      150.0  3433.0
# Ford_Torino                17.0          8         302.0      140.0  3449.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Chevrolet_Chevelle_Malibu          12.0          70       1
# Buick_Skylark_320                  11.5          70       1
# Plymouth_Satellite                 11.0          70       1
# Amc_Rebel_Sst                      12.0          70       1
# Ford_Torino                        10.5          70       1
#
#                                             Car_Name
# car name
# Chevrolet_Chevelle_Malibu  chevrolet chevelle malibu
# Buick_Skylark_320                  buick skylark 320
# Plymouth_Satellite                plymouth satellite
# Amc_Rebel_Sst                          amc rebel sst
# Ford_Torino                              ford torino

# %%
data = ColDataClean(data)
data.head()
data.dtypes
# Out:
#  ****** Printing any Null entries if any **********
# Mpg             False
# Cylinders       False
# Displacement    False
# Horsepower      False
# Weight          False
# Acceleration    False
# Model_Year      False
# Origin          False
# Car_Name        False
# dtype: bool
#  ---------------------Performing String operations on Column head---------------------------
# ('Before:', Index([u'Mpg', u'Cylinders', u'Displacement', u'Horsepower', u'Weight',
#        u'Acceleration', u'Model_Year', u'Origin', u'Car_Name'],
#       dtype='object'))
# ('After: ', Index([u'Mpg', u'Cylinders', u'Displacement', u'Horsepower', u'Weight',
#        u'Acceleration', u'Model_Year', u'Origin', u'Car_Name'],
#       dtype='object'))
#  -------------- Performing String operations on column index i.e., car name ------------------
# ('Before: ', Index([], dtype='object', name=u'car name'))
# ('After: ', Index([], dtype='object', name=u'car name'))
# Mpg             float64
# Cylinders         int64
# Displacement    float64
# Horsepower       object
# Weight          float64
# Acceleration    float64
# Model_Year        int64
# Origin            int64
# Car_Name         object
# dtype: object

# %%
for index,row in data.iterrows():
    if(row['Horsepower'] =='?'):
        print("Yes")
# Out:
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes

# %%
data.dtypes
# Out:
# Mpg             float64
# Cylinders         int64
# Displacement    float64
# Horsepower       object
# Weight          float64
# Acceleration    float64
# Model_Year        int64
# Origin            int64
# Car_Name         object
# dtype: object

# %%
data[data['Horsepower'] =='?']
# Out:
#                        Mpg  Cylinders  Displacement Horsepower  Weight  \
# car name
# Ford_Pinto            25.0          4          98.0          ?  2046.0
# Ford_Maverick         21.0          6         200.0          ?  2875.0
# Renault_Lecar_Deluxe  40.9          4          85.0          ?  1835.0
# Ford_Mustang_Cobra    23.6          4         140.0          ?  2905.0
# Renault_18I           34.5          4         100.0          ?  2320.0
# Amc_Concord_Dl        23.0          4         151.0          ?  3035.0
#
#                       Acceleration  Model_Year  Origin              Car_Name
# car name
# Ford_Pinto                    19.0          71       1            ford pinto
# Ford_Maverick                 17.0          74       1         ford maverick
# Renault_Lecar_Deluxe          17.3          80       2  renault lecar deluxe
# Ford_Mustang_Cobra            14.3          80       1    ford mustang cobra
# Renault_18I                   15.8          81       2           renault 18i
# Amc_Concord_Dl                20.5          82       1        amc concord dl

# %% [markdown]
# **Part III: Data Cleaning/Manipulation - Handling special characters in the dataset **
# Look at the dtype for the dataframe. The horsepower is considered as object. But this needs to be float type. Follow the comments.
# Here in this function, handle the NAN and horsepower column data types to respective one.

# %%
def HandleHP(df, col):
    
    if (df[col].dtype == 'object'):  # Changes only if column is an object!
        
        print('Necessary changes has to be incorporated. !!!')
        
        # print the data type for horsepower column
        print ('The data types for horsepower is :',df[col].dtypes) 
        
        # hint: df[col]=='?' # logical operator, the dataframe looks for string "?". The result is a boolean True or False.
               
        
         # Now, replace the unwanted string '?' in 'Horsepower' column with value 99.0 
        df.at[df[col] =='?',col] = 99.0

         # replaced '?' with 99.0 value of horsepower, check the dtype. Changed to float? 

        print(df[col].dtypes)
    
    
         # change the dtype of 'Horsepower' now. use .astype function
        df[col] = df[col].astype(float,copy=True)
    

        
#         print ('The data types for horsepower is :', df[col].dtype) 
      
    
    return df


print('Before: \n ', data.dtypes)

HandleHP(data,'Horsepower')

print( '\n ')
print('After:\n ', data.dtypes)
# Out:
# ('Before: \n ', Mpg             float64
# Cylinders         int64
# Displacement    float64
# Horsepower       object
# Weight          float64
# Acceleration    float64
# Model_Year        int64
# Origin            int64
# Car_Name         object
# dtype: object)
# Necessary changes has to be incorporated. !!!
# ('The data types for horsepower is :', dtype('O'))
# object
#
#
# ('After:\n ', Mpg             float64
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model_Year        int64
# Origin            int64
# Car_Name         object
# dtype: object)

# %%
data.columns
# Out:
# Index([u'Mpg', u'Cylinders', u'Displacement', u'Horsepower', u'Weight',
#        u'Acceleration', u'Model_Year', u'Origin', u'Car_Name'],
#       dtype='object')

# %% [markdown]
# ** Part IV: Data Aggregation and Grouping   **

# %%
#  Add new columns in data frame for Kmpl (kilometre per litre) & Kmpg (kilometre per gallon) and use mpg data to 
# convert to Kmpl (Note: 1 mpg = 0.425144 kmpl) and (1 mpg = 1.609 Kmpg)

data['Kmpl'] = data['Mpg'] * 0.425144
data['Kmpg'] = data['Mpg'] * 1.609


print (data.head())
# Out:
#                             Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Chevrolet_Chevelle_Malibu  18.0          8         307.0       130.0  3504.0
# Buick_Skylark_320          15.0          8         350.0       165.0  3693.0
# Plymouth_Satellite         18.0          8         318.0       150.0  3436.0
# Amc_Rebel_Sst              16.0          8         304.0       150.0  3433.0
# Ford_Torino                17.0          8         302.0       140.0  3449.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Chevrolet_Chevelle_Malibu          12.0          70       1
# Buick_Skylark_320                  11.5          70       1
# Plymouth_Satellite                 11.0          70       1
# Amc_Rebel_Sst                      12.0          70       1
# Ford_Torino                        10.5          70       1
#
#                                             Car_Name      Kmpl    Kmpg
# car name
# Chevrolet_Chevelle_Malibu  chevrolet chevelle malibu  7.652592  28.962
# Buick_Skylark_320                  buick skylark 320  6.377160  24.135
# Plymouth_Satellite                plymouth satellite  7.652592  28.962
# Amc_Rebel_Sst                          amc rebel sst  6.802304  25.744
# Ford_Torino                              ford torino  7.227448  27.353

# %% [markdown]
# ** Grouping **
# Before grouping, one of the column in the dataset is origin, add another column to produce a column name **'CountryOrigin'**. Based on the resource info, origin indicates the country code i.e., [1,2,3] = ['USA','Europe', 'Asia']. Use dataframe.replace() for this function.
#
# * Group 1 should consists of Groupby objects of 'Model year' and 'country origin'
# * Group 2 should contain only 'Country Origin'
# * Group 3 should contain only 'Model year'

# %%
#  The Origin indicates the country or the continent where the data is originated. Hence, create another 
#  column in the data frame that corresponds to the origin let 1 --> USA, 2--> Europe , 3 --> Asia. 
# Let the country code be stored in the column CountryOrigin.

data['CountryOrigin'] = data['Origin'].replace([1,2,3],['USA','Europe','Asia'])

# create groups here

Group1 = data.groupby(['Model_Year','CountryOrigin'])
Group2 = data.groupby(['CountryOrigin'])
Group3 = data.groupby(['Model_Year'])
Group4 = data.groupby(['CountryOrigin','Model_Year'])



# print the data from Group 2 and Group 3 using iterating over using For-loop

# printing group can be done as shown below. You have to make sure the function prints only 3 for each 
# category
# 

# for x, group in Group1:
#     print (x)
#     print('------------')
#     print (group['Mpg'].head(),'\n')
    
    
#     print('------------')
    
    
    
    
#     print () 


# Other way to print. But needs user to handle error.

for name1, group in Group4:
    print (name1)
    print ('**********************************START****************************************')
    print (group.head(3))
    print ('***********************************END******************************************')
# Out:
# ('Asia', 70)
# **********************************START****************************************
#                         Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Corona_Mark_Ii  24.0          4         113.0        95.0  2372.0
# Datsun_Pl510           27.0          4          97.0        88.0  2130.0
#
#                        Acceleration  Model_Year  Origin  \
# car name
# Toyota_Corona_Mark_Ii          15.0          70       3
# Datsun_Pl510                   14.5          70       3
#
#                                     Car_Name       Kmpl    Kmpg CountryOrigin
# car name
# Toyota_Corona_Mark_Ii  toyota corona mark ii  10.203456  38.616          Asia
# Datsun_Pl510                    datsun pl510  11.478888  43.443          Asia
# ***********************************END******************************************
# ('Asia', 71)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Datsun_Pl510         27.0          4          97.0        88.0  2130.0
# Toyota_Corona        25.0          4         113.0        95.0  2228.0
# Toyota_Corolla_1200  31.0          4          71.0        65.0  1773.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Datsun_Pl510                 14.5          71       3         datsun pl510
# Toyota_Corona                14.0          71       3        toyota corona
# Toyota_Corolla_1200          19.0          71       3  toyota corolla 1200
#
#                           Kmpl    Kmpg CountryOrigin
# car name
# Datsun_Pl510         11.478888  43.443          Asia
# Toyota_Corona        10.628600  40.225          Asia
# Toyota_Corolla_1200  13.179464  49.879          Asia
# ***********************************END******************************************
# ('Asia', 72)
# **********************************START****************************************
#                         Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Corona_Hardtop  24.0          4         113.0        95.0  2278.0
# Mazda_Rx2_Coupe        19.0          3          70.0        97.0  2330.0
# Datsun_510_(Sw)        28.0          4          97.0        92.0  2288.0
#
#                        Acceleration  Model_Year  Origin  \
# car name
# Toyota_Corona_Hardtop          15.5          72       3
# Mazda_Rx2_Coupe                13.5          72       3
# Datsun_510_(Sw)                17.0          72       3
#
#                                     Car_Name       Kmpl    Kmpg CountryOrigin
# car name
# Toyota_Corona_Hardtop  toyota corona hardtop  10.203456  38.616          Asia
# Mazda_Rx2_Coupe              mazda rx2 coupe   8.077736  30.571          Asia
# Datsun_510_(Sw)              datsun 510 (sw)  11.904032  45.052          Asia
# ***********************************END******************************************
# ('Asia', 73)
# **********************************START****************************************
#                 Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Carina  20.0          4          97.0        88.0  2279.0
# Datsun_610     22.0          4         108.0        94.0  2379.0
# Maxda_Rx3      18.0          3          70.0        90.0  2124.0
#
#                Acceleration  Model_Year  Origin       Car_Name      Kmpl  \
# car name
# Toyota_Carina          19.0          73       3  toyota carina  8.502880
# Datsun_610             16.5          73       3     datsun 610  9.353168
# Maxda_Rx3              13.5          73       3      maxda rx3  7.652592
#
#                  Kmpg CountryOrigin
# car name
# Toyota_Carina  32.180          Asia
# Datsun_610     35.398          Asia
# Maxda_Rx3      28.962          Asia
# ***********************************END******************************************
# ('Asia', 74)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Datsun_B210          31.0          4          79.0        67.0  1950.0
# Toyota_Corolla_1200  32.0          4          71.0        65.0  1836.0
# Toyota_Corona        31.0          4          76.0        52.0  1649.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Datsun_B210                  19.0          74       3          datsun b210
# Toyota_Corolla_1200          21.0          74       3  toyota corolla 1200
# Toyota_Corona                16.5          74       3        toyota corona
#
#                           Kmpl    Kmpg CountryOrigin
# car name
# Datsun_B210          13.179464  49.879          Asia
# Toyota_Corolla_1200  13.604608  51.488          Asia
# Toyota_Corona        13.179464  49.879          Asia
# ***********************************END******************************************
# ('Asia', 75)
# **********************************START****************************************
#                  Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Corolla  29.0          4          97.0        75.0  2171.0
# Toyota_Corona   24.0          4         134.0        96.0  2702.0
# Datsun_710      24.0          4         119.0        97.0  2545.0
#
#                 Acceleration  Model_Year  Origin        Car_Name       Kmpl  \
# car name
# Toyota_Corolla          16.0          75       3  toyota corolla  12.329176
# Toyota_Corona           13.5          75       3   toyota corona  10.203456
# Datsun_710              17.0          75       3      datsun 710  10.203456
#
#                   Kmpg CountryOrigin
# car name
# Toyota_Corolla  46.661          Asia
# Toyota_Corona   38.616          Asia
# Datsun_710      38.616          Asia
# ***********************************END******************************************
# ('Asia', 76)
# **********************************START****************************************
#                  Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Honda_Civic     33.0          4          91.0        53.0  1795.0
# Datsun_B-210    32.0          4          85.0        70.0  1990.0
# Toyota_Corolla  28.0          4          97.0        75.0  2155.0
#
#                 Acceleration  Model_Year  Origin        Car_Name       Kmpl  \
# car name
# Honda_Civic             17.4          76       3     honda civic  14.029752
# Datsun_B-210            17.0          76       3    datsun b-210  13.604608
# Toyota_Corolla          16.4          76       3  toyota corolla  11.904032
#
#                   Kmpg CountryOrigin
# car name
# Honda_Civic     53.097          Asia
# Datsun_B-210    51.488          Asia
# Toyota_Corolla  45.052          Asia
# ***********************************END******************************************
# ('Asia', 77)
# **********************************START****************************************
#                           Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Honda_Accord_Cvcc        31.5          4          98.0        68.0  2045.0
# Datsun_F-10_Hatchback    33.5          4          85.0        70.0  1945.0
# Toyota_Corolla_Liftback  26.0          4          97.0        75.0  2265.0
#
#                          Acceleration  Model_Year  Origin  \
# car name
# Honda_Accord_Cvcc                18.5          77       3
# Datsun_F-10_Hatchback            16.8          77       3
# Toyota_Corolla_Liftback          18.2          77       3
#
#                                         Car_Name       Kmpl     Kmpg  \
# car name
# Honda_Accord_Cvcc              honda accord cvcc  13.392036  50.6835
# Datsun_F-10_Hatchback      datsun f-10 hatchback  14.242324  53.9015
# Toyota_Corolla_Liftback  toyota corolla liftback  11.053744  41.8340
#
#                         CountryOrigin
# car name
# Honda_Accord_Cvcc                Asia
# Datsun_F-10_Hatchback            Asia
# Toyota_Corolla_Liftback          Asia
# ***********************************END******************************************
# ('Asia', 78)
# **********************************START****************************************
#                    Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Mazda_Glc_Deluxe  32.8          4          78.0        52.0  1985.0
# Datsun_B210_Gx    39.4          4          85.0        70.0  2070.0
# Honda_Civic_Cvcc  36.1          4          91.0        60.0  1800.0
#
#                   Acceleration  Model_Year  Origin          Car_Name  \
# car name
# Mazda_Glc_Deluxe          19.4          78       3  mazda glc deluxe
# Datsun_B210_Gx            18.6          78       3    datsun b210 gx
# Honda_Civic_Cvcc          16.4          78       3  honda civic cvcc
#
#                        Kmpl     Kmpg CountryOrigin
# car name
# Mazda_Glc_Deluxe  13.944723  52.7752          Asia
# Datsun_B210_Gx    16.750674  63.3946          Asia
# Honda_Civic_Cvcc  15.347698  58.0849          Asia
# ***********************************END******************************************
# ('Asia', 79)
# **********************************START****************************************
#                    Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Maxda_Glc_Deluxe  34.1          4          86.0        65.0  1975.0
# Datsun_210        31.8          4          85.0        65.0  2020.0
#
#                   Acceleration  Model_Year  Origin          Car_Name  \
# car name
# Maxda_Glc_Deluxe          15.2          79       3  maxda glc deluxe
# Datsun_210                19.2          79       3        datsun 210
#
#                        Kmpl     Kmpg CountryOrigin
# car name
# Maxda_Glc_Deluxe  14.497410  54.8669          Asia
# Datsun_210        13.519579  51.1662          Asia
# ***********************************END******************************************
# ('Asia', 80)
# **********************************START****************************************
#                          Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Corolla_Tercel   38.1          4          89.0        60.0  1968.0
# Datsun_310              37.2          4          86.0        65.0  2019.0
# Toyota_Corona_Liftback  29.8          4         134.0        90.0  2711.0
#
#                         Acceleration  Model_Year  Origin  \
# car name
# Toyota_Corolla_Tercel           18.8          80       3
# Datsun_310                      16.4          80       3
# Toyota_Corona_Liftback          15.5          80       3
#
#                                       Car_Name       Kmpl     Kmpg  \
# car name
# Toyota_Corolla_Tercel    toyota corolla tercel  16.197986  61.3029
# Datsun_310                          datsun 310  15.815357  59.8548
# Toyota_Corona_Liftback  toyota corona liftback  12.669291  47.9482
#
#                        CountryOrigin
# car name
# Toyota_Corolla_Tercel           Asia
# Datsun_310                      Asia
# Toyota_Corona_Liftback          Asia
# ***********************************END******************************************
# ('Asia', 81)
# **********************************START****************************************
#                    Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Toyota_Starlet    39.1          4          79.0        58.0  1755.0
# Honda_Civic_1300  35.1          4          81.0        60.0  1760.0
# Subaru            32.3          4          97.0        67.0  2065.0
#
#                   Acceleration  Model_Year  Origin          Car_Name  \
# car name
# Toyota_Starlet            16.9          81       3    toyota starlet
# Honda_Civic_1300          16.1          81       3  honda civic 1300
# Subaru                    17.8          81       3            subaru
#
#                        Kmpl     Kmpg CountryOrigin
# car name
# Toyota_Starlet    16.623130  62.9119          Asia
# Honda_Civic_1300  14.922554  56.4759          Asia
# Subaru            13.732151  51.9707          Asia
# ***********************************END******************************************
# ('Asia', 82)
# **********************************START****************************************
#                      Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Mazda_Glc_Custom_L  37.0          4          91.0        68.0  2025.0
# Mazda_Glc_Custom    31.0          4          91.0        68.0  1970.0
# Nissan_Stanza_Xe    36.0          4         120.0        88.0  2160.0
#
#                     Acceleration  Model_Year  Origin            Car_Name  \
# car name
# Mazda_Glc_Custom_L          18.2          82       3  mazda glc custom l
# Mazda_Glc_Custom            17.6          82       3    mazda glc custom
# Nissan_Stanza_Xe            14.5          82       3    nissan stanza xe
#
#                          Kmpl    Kmpg CountryOrigin
# car name
# Mazda_Glc_Custom_L  15.730328  59.533          Asia
# Mazda_Glc_Custom    13.179464  49.879          Asia
# Nissan_Stanza_Xe    15.305184  57.924          Asia
# ***********************************END******************************************
# ('Europe', 70)
# **********************************START****************************************
#                                Mpg  Cylinders  Displacement  Horsepower  \
# car name
# Volkswagen_1131_Deluxe_Sedan  26.0          4          97.0        46.0
# Peugeot_504                   25.0          4         110.0        87.0
# Audi_100_Ls                   24.0          4         107.0        90.0
#
#                               Weight  Acceleration  Model_Year  Origin  \
# car name
# Volkswagen_1131_Deluxe_Sedan  1835.0          20.5          70       2
# Peugeot_504                   2672.0          17.5          70       2
# Audi_100_Ls                   2430.0          14.5          70       2
#
#                                                   Car_Name       Kmpl    Kmpg  \
# car name
# Volkswagen_1131_Deluxe_Sedan  volkswagen 1131 deluxe sedan  11.053744  41.834
# Peugeot_504                                    peugeot 504  10.628600  40.225
# Audi_100_Ls                                    audi 100 ls  10.203456  38.616
#
#                              CountryOrigin
# car name
# Volkswagen_1131_Deluxe_Sedan        Europe
# Peugeot_504                         Europe
# Audi_100_Ls                         Europe
# ***********************************END******************************************
# ('Europe', 71)
# **********************************START****************************************
#               Mpg  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# car name
# Opel_1900    28.0          4         116.0        90.0  2123.0          14.0
# Peugeot_304  30.0          4          79.0        70.0  2074.0          19.5
# Fiat_124B    30.0          4          88.0        76.0  2065.0          14.5
#
#              Model_Year  Origin     Car_Name       Kmpl    Kmpg CountryOrigin
# car name
# Opel_1900            71       2    opel 1900  11.904032  45.052        Europe
# Peugeot_304          71       2  peugeot 304  12.754320  48.270        Europe
# Fiat_124B            71       2    fiat 124b  12.754320  48.270        Europe
# ***********************************END******************************************
# ('Europe', 72)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Volkswagen_Type_3    23.0          4          97.0        54.0  2254.0
# Volvo_145E_(Sw)      18.0          4         121.0       112.0  2933.0
# Volkswagen_411_(Sw)  22.0          4         121.0        76.0  2511.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Volkswagen_Type_3            23.5          72       2    volkswagen type 3
# Volvo_145E_(Sw)              14.5          72       2      volvo 145e (sw)
# Volkswagen_411_(Sw)          18.0          72       2  volkswagen 411 (sw)
#
#                          Kmpl    Kmpg CountryOrigin
# car name
# Volkswagen_Type_3    9.778312  37.007        Europe
# Volvo_145E_(Sw)      7.652592  28.962        Europe
# Volkswagen_411_(Sw)  9.353168  35.398        Europe
# ***********************************END******************************************
# ('Europe', 73)
# **********************************START****************************************
#                           Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Volkswagen_Super_Beetle  26.0          4          97.0        46.0  1950.0
# Fiat_124_Sport_Coupe     26.0          4          98.0        90.0  2265.0
# Fiat_128                 29.0          4          68.0        49.0  1867.0
#
#                          Acceleration  Model_Year  Origin  \
# car name
# Volkswagen_Super_Beetle          21.0          73       2
# Fiat_124_Sport_Coupe             15.5          73       2
# Fiat_128                         19.5          73       2
#
#                                         Car_Name       Kmpl    Kmpg  \
# car name
# Volkswagen_Super_Beetle  volkswagen super beetle  11.053744  41.834
# Fiat_124_Sport_Coupe        fiat 124 sport coupe  11.053744  41.834
# Fiat_128                                fiat 128  12.329176  46.661
#
#                         CountryOrigin
# car name
# Volkswagen_Super_Beetle        Europe
# Fiat_124_Sport_Coupe           Europe
# Fiat_128                       Europe
# ***********************************END******************************************
# ('Europe', 74)
# **********************************START****************************************
#                     Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Audi_Fox           29.0          4          98.0        83.0  2219.0
# Volkswagen_Dasher  26.0          4          79.0        67.0  1963.0
# Opel_Manta         26.0          4          97.0        78.0  2300.0
#
#                    Acceleration  Model_Year  Origin           Car_Name  \
# car name
# Audi_Fox                   16.5          74       2           audi fox
# Volkswagen_Dasher          15.5          74       2  volkswagen dasher
# Opel_Manta                 14.5          74       2         opel manta
#
#                         Kmpl    Kmpg CountryOrigin
# car name
# Audi_Fox           12.329176  46.661        Europe
# Volkswagen_Dasher  11.053744  41.834        Europe
# Opel_Manta         11.053744  41.834        Europe
# ***********************************END******************************************
# ('Europe', 75)
# **********************************START****************************************
#                     Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Volkswagen_Dasher  25.0          4          90.0        71.0  2223.0
# Volkswagen_Rabbit  29.0          4          90.0        70.0  1937.0
# Audi_100Ls         23.0          4         115.0        95.0  2694.0
#
#                    Acceleration  Model_Year  Origin           Car_Name  \
# car name
# Volkswagen_Dasher          16.5          75       2  volkswagen dasher
# Volkswagen_Rabbit          14.0          75       2  volkswagen rabbit
# Audi_100Ls                 15.0          75       2         audi 100ls
#
#                         Kmpl    Kmpg CountryOrigin
# car name
# Volkswagen_Dasher  10.628600  40.225        Europe
# Volkswagen_Rabbit  12.329176  46.661        Europe
# Audi_100Ls          9.778312  37.007        Europe
# ***********************************END******************************************
# ('Europe', 76)
# **********************************START****************************************
#                Mpg  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# car name
# Fiat_131      28.0          4         107.0        86.0  2464.0          15.5
# Opel_1900     25.0          4         116.0        81.0  2220.0          16.9
# Renault_12Tl  27.0          4         101.0        83.0  2202.0          15.3
#
#               Model_Year  Origin      Car_Name       Kmpl    Kmpg  \
# car name
# Fiat_131              76       2      fiat 131  11.904032  45.052
# Opel_1900             76       2     opel 1900  10.628600  40.225
# Renault_12Tl          76       2  renault 12tl  11.478888  43.443
#
#              CountryOrigin
# car name
# Fiat_131            Europe
# Opel_1900           Europe
# Renault_12Tl        Europe
# ***********************************END******************************************
# ('Europe', 77)
# **********************************START****************************************
#                            Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Renault_5_Gtl             36.0          4          79.0        58.0  1825.0
# Volkswagen_Rabbit_Custom  29.0          4          97.0        78.0  1940.0
# Volkswagen_Dasher         30.5          4          97.0        78.0  2190.0
#
#                           Acceleration  Model_Year  Origin  \
# car name
# Renault_5_Gtl                     18.6          77       2
# Volkswagen_Rabbit_Custom          14.5          77       2
# Volkswagen_Dasher                 14.1          77       2
#
#                                           Car_Name       Kmpl     Kmpg  \
# car name
# Renault_5_Gtl                        renault 5 gtl  15.305184  57.9240
# Volkswagen_Rabbit_Custom  volkswagen rabbit custom  12.329176  46.6610
# Volkswagen_Dasher                volkswagen dasher  12.966892  49.0745
#
#                          CountryOrigin
# car name
# Renault_5_Gtl                   Europe
# Volkswagen_Rabbit_Custom        Europe
# Volkswagen_Dasher               Europe
# ***********************************END******************************************
# ('Europe', 78)
# **********************************START****************************************
#                                   Mpg  Cylinders  Displacement  Horsepower  \
# car name
# Volkswagen_Rabbit_Custom_Diesel  43.1          4          90.0        48.0
# Audi_5000                        20.3          5         131.0       103.0
# Volvo_264Gl                      17.0          6         163.0       125.0
#
#                                  Weight  Acceleration  Model_Year  Origin  \
# car name
# Volkswagen_Rabbit_Custom_Diesel  1985.0          21.5          78       2
# Audi_5000                        2830.0          15.9          78       2
# Volvo_264Gl                      3140.0          13.6          78       2
#
#                                                         Car_Name       Kmpl  \
# car name
# Volkswagen_Rabbit_Custom_Diesel  volkswagen rabbit custom diesel  18.323706
# Audi_5000                                              audi 5000   8.630423
# Volvo_264Gl                                          volvo 264gl   7.227448
#
#                                     Kmpg CountryOrigin
# car name
# Volkswagen_Rabbit_Custom_Diesel  69.3479        Europe
# Audi_5000                        32.6627        Europe
# Volvo_264Gl                      27.3530        Europe
# ***********************************END******************************************
# ('Europe', 79)
# **********************************START****************************************
#                      Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Vw_Rabbit_Custom    31.9          4          89.0        71.0  1925.0
# Mercedes_Benz_300D  25.4          5         183.0        77.0  3530.0
# Peugeot_504         27.2          4         141.0        71.0  3190.0
#
#                     Acceleration  Model_Year  Origin            Car_Name  \
# car name
# Vw_Rabbit_Custom            14.0          79       2    vw rabbit custom
# Mercedes_Benz_300D          20.1          79       2  mercedes benz 300d
# Peugeot_504                 24.8          79       2         peugeot 504
#
#                          Kmpl     Kmpg CountryOrigin
# car name
# Vw_Rabbit_Custom    13.562094  51.3271        Europe
# Mercedes_Benz_300D  10.798658  40.8686        Europe
# Peugeot_504         11.563917  43.7648        Europe
# ***********************************END******************************************
# ('Europe', 80)
# **********************************START****************************************
#                        Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Vw_Rabbit             41.5          4          98.0        76.0  2144.0
# Audi_4000             34.3          4          97.0        78.0  2188.0
# Vw_Rabbit_C_(Diesel)  44.3          4          90.0        48.0  2085.0
#
#                       Acceleration  Model_Year  Origin              Car_Name  \
# car name
# Vw_Rabbit                     14.7          80       2             vw rabbit
# Audi_4000                     15.8          80       2             audi 4000
# Vw_Rabbit_C_(Diesel)          21.7          80       2  vw rabbit c (diesel)
#
#                            Kmpl     Kmpg CountryOrigin
# car name
# Vw_Rabbit             17.643476  66.7735        Europe
# Audi_4000             14.582439  55.1887        Europe
# Vw_Rabbit_C_(Diesel)  18.833879  71.2787        Europe
# ***********************************END******************************************
# ('Europe', 81)
# **********************************START****************************************
#                             Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Volkswagen_Jetta           33.0          4         105.0        74.0  2190.0
# Renault_18I                34.5          4         100.0        99.0  2320.0
# Peugeot_505S_Turbo_Diesel  28.1          4         141.0        80.0  3230.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Volkswagen_Jetta                   14.2          81       2
# Renault_18I                        15.8          81       2
# Peugeot_505S_Turbo_Diesel          20.4          81       2
#
#                                             Car_Name       Kmpl     Kmpg  \
# car name
# Volkswagen_Jetta                    volkswagen jetta  14.029752  53.0970
# Renault_18I                              renault 18i  14.667468  55.5105
# Peugeot_505S_Turbo_Diesel  peugeot 505s turbo diesel  11.946546  45.2129
#
#                           CountryOrigin
# car name
# Volkswagen_Jetta                 Europe
# Renault_18I                      Europe
# Peugeot_505S_Turbo_Diesel        Europe
# ***********************************END******************************************
# ('Europe', 82)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Volkswagen_Rabbit_L  36.0          4         105.0        74.0  1980.0
# Vw_Pickup            44.0          4          97.0        52.0  2130.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Volkswagen_Rabbit_L          15.3          82       2  volkswagen rabbit l
# Vw_Pickup                    24.6          82       2            vw pickup
#
#                           Kmpl    Kmpg CountryOrigin
# car name
# Volkswagen_Rabbit_L  15.305184  57.924        Europe
# Vw_Pickup            18.706336  70.796        Europe
# ***********************************END******************************************
# ('USA', 70)
# **********************************START****************************************
#                             Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Chevrolet_Chevelle_Malibu  18.0          8         307.0       130.0  3504.0
# Buick_Skylark_320          15.0          8         350.0       165.0  3693.0
# Plymouth_Satellite         18.0          8         318.0       150.0  3436.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Chevrolet_Chevelle_Malibu          12.0          70       1
# Buick_Skylark_320                  11.5          70       1
# Plymouth_Satellite                 11.0          70       1
#
#                                             Car_Name      Kmpl    Kmpg  \
# car name
# Chevrolet_Chevelle_Malibu  chevrolet chevelle malibu  7.652592  28.962
# Buick_Skylark_320                  buick skylark 320  6.377160  24.135
# Plymouth_Satellite                plymouth satellite  7.652592  28.962
#
#                           CountryOrigin
# car name
# Chevrolet_Chevelle_Malibu           USA
# Buick_Skylark_320                   USA
# Plymouth_Satellite                  USA
# ***********************************END******************************************
# ('USA', 71)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Chevrolet_Vega_2300  28.0          4         140.0        90.0  2264.0
# Ford_Pinto           25.0          4          98.0        99.0  2046.0
# Amc_Gremlin          19.0          6         232.0       100.0  2634.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Chevrolet_Vega_2300          15.5          71       1  chevrolet vega 2300
# Ford_Pinto                   19.0          71       1           ford pinto
# Amc_Gremlin                  13.0          71       1          amc gremlin
#
#                           Kmpl    Kmpg CountryOrigin
# car name
# Chevrolet_Vega_2300  11.904032  45.052           USA
# Ford_Pinto           10.628600  40.225           USA
# Amc_Gremlin           8.077736  30.571           USA
# ***********************************END******************************************
# ('USA', 72)
# **********************************START****************************************
#                       Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Dodge_Colt_Hardtop   25.0          4          97.5        80.0  2126.0
# Chevrolet_Vega       20.0          4         140.0        90.0  2408.0
# Ford_Pinto_Runabout  21.0          4         122.0        86.0  2226.0
#
#                      Acceleration  Model_Year  Origin             Car_Name  \
# car name
# Dodge_Colt_Hardtop           17.0          72       1   dodge colt hardtop
# Chevrolet_Vega               19.5          72       1       chevrolet vega
# Ford_Pinto_Runabout          16.5          72       1  ford pinto runabout
#
#                           Kmpl    Kmpg CountryOrigin
# car name
# Dodge_Colt_Hardtop   10.628600  40.225           USA
# Chevrolet_Vega        8.502880  32.180           USA
# Ford_Pinto_Runabout   8.928024  33.789           USA
# ***********************************END******************************************
# ('USA', 73)
# **********************************START****************************************
#                     Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Buick_Century_350  13.0          8         350.0       175.0  4100.0
# Amc_Matador        14.0          8         304.0       150.0  3672.0
# Chevrolet_Malibu   13.0          8         350.0       145.0  3988.0
#
#                    Acceleration  Model_Year  Origin           Car_Name  \
# car name
# Buick_Century_350          13.0          73       1  buick century 350
# Amc_Matador                11.5          73       1        amc matador
# Chevrolet_Malibu           13.0          73       1   chevrolet malibu
#
#                        Kmpl    Kmpg CountryOrigin
# car name
# Buick_Century_350  5.526872  20.917           USA
# Amc_Matador        5.952016  22.526           USA
# Chevrolet_Malibu   5.526872  20.917           USA
# ***********************************END******************************************
# ('USA', 74)
# **********************************START****************************************
#                   Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Plymouth_Duster  20.0          6         198.0        95.0  3102.0
# Ford_Maverick    21.0          6         200.0        99.0  2875.0
# Amc_Hornet       19.0          6         232.0       100.0  2901.0
#
#                  Acceleration  Model_Year  Origin         Car_Name      Kmpl  \
# car name
# Plymouth_Duster          16.5          74       1  plymouth duster  8.502880
# Ford_Maverick            17.0          74       1    ford maverick  8.928024
# Amc_Hornet               16.0          74       1       amc hornet  8.077736
#
#                    Kmpg CountryOrigin
# car name
# Plymouth_Duster  32.180           USA
# Ford_Maverick    33.789           USA
# Amc_Hornet       30.571           USA
# ***********************************END******************************************
# ('USA', 75)
# **********************************START****************************************
#                           Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Plymouth_Valiant_Custom  19.0          6         225.0        95.0  3264.0
# Chevrolet_Nova           18.0          6         250.0       105.0  3459.0
# Mercury_Monarch          15.0          6         250.0        72.0  3432.0
#
#                          Acceleration  Model_Year  Origin  \
# car name
# Plymouth_Valiant_Custom          16.0          75       1
# Chevrolet_Nova                   16.0          75       1
# Mercury_Monarch                  21.0          75       1
#
#                                         Car_Name      Kmpl    Kmpg  \
# car name
# Plymouth_Valiant_Custom  plymouth valiant custom  8.077736  30.571
# Chevrolet_Nova                    chevrolet nova  7.652592  28.962
# Mercury_Monarch                  mercury monarch  6.377160  24.135
#
#                         CountryOrigin
# car name
# Plymouth_Valiant_Custom           USA
# Chevrolet_Nova                    USA
# Mercury_Monarch                   USA
# ***********************************END******************************************
# ('USA', 76)
# **********************************START****************************************
#                                     Mpg  Cylinders  Displacement  Horsepower  \
# car name
# Capri_Ii                           25.0          4         140.0        92.0
# Dodge_Colt                         26.0          4          98.0        79.0
# Chevrolet_Chevelle_Malibu_Classic  17.5          8         305.0       140.0
#
#                                    Weight  Acceleration  Model_Year  Origin  \
# car name
# Capri_Ii                           2572.0          14.9          76       1
# Dodge_Colt                         2255.0          17.7          76       1
# Chevrolet_Chevelle_Malibu_Classic  4215.0          13.0          76       1
#
#                                                             Car_Name  \
# car name
# Capri_Ii                                                    capri ii
# Dodge_Colt                                                dodge colt
# Chevrolet_Chevelle_Malibu_Classic  chevrolet chevelle malibu classic
#
#                                         Kmpl     Kmpg CountryOrigin
# car name
# Capri_Ii                           10.628600  40.2250           USA
# Dodge_Colt                         11.053744  41.8340           USA
# Chevrolet_Chevelle_Malibu_Classic   7.440020  28.1575           USA
# ***********************************END******************************************
# ('USA', 77)
# **********************************START****************************************
#                             Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Buick_Opel_Isuzu_Deluxe    30.0          4         111.0        80.0  2155.0
# Plymouth_Arrow_Gs          25.5          4         122.0        96.0  2300.0
# Chevrolet_Caprice_Classic  17.5          8         305.0       145.0  3880.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Buick_Opel_Isuzu_Deluxe            14.8          77       1
# Plymouth_Arrow_Gs                  15.5          77       1
# Chevrolet_Caprice_Classic          12.5          77       1
#
#                                             Car_Name       Kmpl     Kmpg  \
# car name
# Buick_Opel_Isuzu_Deluxe      buick opel isuzu deluxe  12.754320  48.2700
# Plymouth_Arrow_Gs                  plymouth arrow gs  10.841172  41.0295
# Chevrolet_Caprice_Classic  chevrolet caprice classic   7.440020  28.1575
#
#                           CountryOrigin
# car name
# Buick_Opel_Isuzu_Deluxe             USA
# Plymouth_Arrow_Gs                   USA
# Chevrolet_Caprice_Classic           USA
# ***********************************END******************************************
# ('USA', 78)
# **********************************START****************************************
#                                     Mpg  Cylinders  Displacement  Horsepower  \
# car name
# Ford_Fiesta                        36.1          4          98.0        66.0
# Oldsmobile_Cutlass_Salon_Brougham  19.9          8         260.0       110.0
# Dodge_Diplomat                     19.4          8         318.0       140.0
#
#                                    Weight  Acceleration  Model_Year  Origin  \
# car name
# Ford_Fiesta                        1800.0          14.4          78       1
# Oldsmobile_Cutlass_Salon_Brougham  3365.0          15.5          78       1
# Dodge_Diplomat                     3735.0          13.2          78       1
#
#                                                             Car_Name  \
# car name
# Ford_Fiesta                                              ford fiesta
# Oldsmobile_Cutlass_Salon_Brougham  oldsmobile cutlass salon brougham
# Dodge_Diplomat                                        dodge diplomat
#
#                                         Kmpl     Kmpg CountryOrigin
# car name
# Ford_Fiesta                        15.347698  58.0849           USA
# Oldsmobile_Cutlass_Salon_Brougham   8.460366  32.0191           USA
# Dodge_Diplomat                      8.247794  31.2146           USA
# ***********************************END******************************************
# ('USA', 79)
# **********************************START****************************************
#                     Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Pontiac_Lemans_V6  21.5          6         231.0       115.0  3245.0
# Mercury_Zephyr_6   19.8          6         200.0        85.0  2990.0
# Ford_Fairmont_4    22.3          4         140.0        88.0  2890.0
#
#                    Acceleration  Model_Year  Origin           Car_Name  \
# car name
# Pontiac_Lemans_V6          15.4          79       1  pontiac lemans v6
# Mercury_Zephyr_6           18.2          79       1   mercury zephyr 6
# Ford_Fairmont_4            17.3          79       1    ford fairmont 4
#
#                        Kmpl     Kmpg CountryOrigin
# car name
# Pontiac_Lemans_V6  9.140596  34.5935           USA
# Mercury_Zephyr_6   8.417851  31.8582           USA
# Ford_Fairmont_4    9.480711  35.8807           USA
# ***********************************END******************************************
# ('USA', 80)
# **********************************START****************************************
#                      Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Chevrolet_Chevette  32.1          4          98.0        70.0  2120.0
# Chevrolet_Citation  28.0          4         151.0        90.0  2678.0
# Ford_Fairmont       26.4          4         140.0        88.0  2870.0
#
#                     Acceleration  Model_Year  Origin            Car_Name  \
# car name
# Chevrolet_Chevette          15.5          80       1  chevrolet chevette
# Chevrolet_Citation          16.5          80       1  chevrolet citation
# Ford_Fairmont               18.1          80       1       ford fairmont
#
#                          Kmpl     Kmpg CountryOrigin
# car name
# Chevrolet_Chevette  13.647122  51.6489           USA
# Chevrolet_Citation  11.904032  45.0520           USA
# Ford_Fairmont       11.223802  42.4776           USA
# ***********************************END******************************************
# ('USA', 81)
# **********************************START****************************************
#                          Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Plymouth_Reliant        27.2          4         135.0        84.0  2490.0
# Buick_Skylark           26.6          4         151.0        84.0  2635.0
# Dodge_Aries_Wagon_(Sw)  25.8          4         156.0        92.0  2620.0
#
#                         Acceleration  Model_Year  Origin  \
# car name
# Plymouth_Reliant                15.7          81       1
# Buick_Skylark                   16.4          81       1
# Dodge_Aries_Wagon_(Sw)          14.4          81       1
#
#                                       Car_Name       Kmpl     Kmpg  \
# car name
# Plymouth_Reliant              plymouth reliant  11.563917  43.7648
# Buick_Skylark                    buick skylark  11.308830  42.7994
# Dodge_Aries_Wagon_(Sw)  dodge aries wagon (sw)  10.968715  41.5122
#
#                        CountryOrigin
# car name
# Plymouth_Reliant                 USA
# Buick_Skylark                    USA
# Dodge_Aries_Wagon_(Sw)           USA
# ***********************************END******************************************
# ('USA', 82)
# **********************************START****************************************
#                             Mpg  Cylinders  Displacement  Horsepower  Weight  \
# car name
# Chevrolet_Cavalier         28.0          4         112.0        88.0  2605.0
# Chevrolet_Cavalier_Wagon   27.0          4         112.0        88.0  2640.0
# Chevrolet_Cavalier_2-Door  34.0          4         112.0        88.0  2395.0
#
#                            Acceleration  Model_Year  Origin  \
# car name
# Chevrolet_Cavalier                 19.6          82       1
# Chevrolet_Cavalier_Wagon           18.6          82       1
# Chevrolet_Cavalier_2-Door          18.0          82       1
#
#                                             Car_Name       Kmpl    Kmpg  \
# car name
# Chevrolet_Cavalier                chevrolet cavalier  11.904032  45.052
# Chevrolet_Cavalier_Wagon    chevrolet cavalier wagon  11.478888  43.443
# Chevrolet_Cavalier_2-Door  chevrolet cavalier 2-door  14.454896  54.706
#
#                           CountryOrigin
# car name
# Chevrolet_Cavalier                  USA
# Chevrolet_Cavalier_Wagon            USA
# Chevrolet_Cavalier_2-Door           USA
# ***********************************END******************************************

# %% [markdown]
# ** Part V: Data exploration and analysis**
#
# Create a function by name ** YearlyMileage() ** and observe the mileage performance over the period of time. Use plotting tools and plots such as line, bar or scatter.
# Plot attributes such as 'Mpg','Horsepower','Cylinders','Displacement','CountryOrigin' in scatter plot matrix.
#
# The function here has to provide the
# 1. Yearly average mileage and produce an appropriate plot (either line or bar whichever is appropriate)
# 2. Edit the properties of the plot to display more user friendly.
# 3. Produce another scatter matrix for attributes such as mpg, horsepower, cylinders, displacement and country origin.
# 4. try the same scatter matrix attributes using seaborn library.
# 5. In all this plots, make sure user understands the data i.e., add title, axis, lables, legends, colors etc.

# %%
# Calculate mean for all the cars for each year starting from 1970 to 1982. Plot the profile for example use Bar plot.
# Please maintain the figsize to atleast 12,6.
# The below cell need to present a conclusion of the mpg over the period of 1970-1982. 
# The relationship between the attributes can be understood by looking into the scatter plot. Import seaborn 

# Use Aggregate property of the group 1-3 to produce a mean for yearly data
def plot_bar(my_group):
    YearMileage = my_group['Mpg'].mean()
#     print(YearMileage)
    YearMileage.plot.bar(figsize=(10,5))
    plt.title("Mpg")
    plt.ylabel('Mpg')
    plt.show()
    return

# Analyze the result by plotting in either bar or line plot.

plot_bar(Group1)
plot_bar(Group2)
plot_bar(Group3)
plot_bar(Group4)


# Include the property to make it look good.

# %%
# https://stackoverflow.com/questions/7941207/is-there-a-function-to-make-scatterplot-matrices-in-matplotlib
# Scatter Matrix plot is very important for understanding of the dataset and its profile. 
# But scatter matrix can be done using library from pandas.plotting and importing scatter matrix from it.

# Import the required module here:

from pandas.plotting import scatter_matrix as sm



# Creating a function here to return a well-edited fig


def plotscatterMatrix(data):
    
    sm(data,alpha= 0.2,figsize=(10,10))
    plt.suptitle("Scatter plot")
    
 
    return 


# Function call 
plotscatterMatrix(data[['Mpg','Horsepower','Cylinders','Displacement','CountryOrigin']])

# plotscatterMatrix(data[['Mpg','Horsepower','Cylinders','Displacement','CountryOrigin']], diagonal = 'kde')
plt.show()

# %%
import seaborn as sea

sea.set()

sea.pairplot(data[['Mpg','Horsepower','Cylinders','Displacement','CountryOrigin']], size = 3.0,hue ='Cylinders')

plt.show()
# Out:
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/campus11/nkattapr/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
